# %%
import yfinance as yf
import pandas as pd
import time
import random
import pandas as pd
from datetime import datetime

# %%
def load_data(tickers, fields=("Close", "Volume")):
    dfs = {field: pd.DataFrame() for field in fields}

    for k, v in tickers.items():
        print(f"Loading data for {k} from {v['start_date']} to {v['end_date']}...")
        raw = yf.download(
            v["tickers"],
            start=v["start_date"],
            end=v["end_date"],
            auto_adjust=False,
        )
        for field in fields:
            if field in raw.columns:
                dfs[field][k] = raw[field]
        time.sleep(random.uniform(0.5, 3.0))

    return dfs

# %%
top_50_us_tickers = [
"AAPL", "MSFT", "NVDA", "AMZN", "GOOG", "GOOGL", "META", "BRK-B", "TSLA", "AVGO",
"JPM", "WMT", "LLY", "V", "MA", "XOM", "UNH", "COST", "ORCL", "NFLX",
"JNJ", "HD", "PG", "BAC", "ABBV", "KO", "CRM", "CVX", "MRK", "AMD",
"PEP", "TMO", "CSCO", "WFC", "ACN", "MCD", "IBM", "ABT", "LIN", "GE",
"DHR", "DIS", "INTU", "TXN", "CAT", "QCOM", "AMGN", "VZ", "RTX", "SPGI"
]

top_50_europe_tickers = [
"ASML.AS", "NVO", "SAP.DE", "MC.PA", "NESN.SW", "AZN.L", "SHEL.L", "NOVO-B.CO", "ROG.SW", "OR.PA",
"HSBA.L", "ULVR.L", "SIE.DE", "SU.PA", "ALV.DE", "SAN.PA", "BP.L", "AIR.PA", "REL.L", "UBSG.SW",
"RIO.L", "BATS.L", "GSK.L", "DG.PA", "RMS.PA", "AI.PA", "TTE.PA", "EL.PA", "PRX.AS", "INGA.AS",
"AD.AS", "WKL.AS", "ABI.BR", "IBE.MC", "SAN.MC", "BBVA.MC", "ENEL.MI", "ISP.MI", "UCG.MI", "RACE.MI",
"CS.PA", "BNP.PA", "SAF.PA", "CAP.PA", "DTE.DE", "BAS.DE", "IFX.DE", "BAYN.DE", "NOKIA.HE", "VOLV-B.ST"
]

top_50_crypto_tickers = [
"BTC-USD", "ETH-USD", "BNB-USD", "SOL-USD", "XRP-USD", "DOGE-USD", "ADA-USD", "TRX-USD", "TON11419-USD",
"AVAX-USD", "SHIB-USD", "WBTC-USD", "LINK-USD", "BCH-USD", "DOT-USD", "LEO-USD", "DAI-USD", "LTC-USD",
"MATIC-USD", "UNI7083-USD", "PEPE24478-USD", "ICP-USD", "ETC-USD", "XMR-USD", "APT21794-USD", "NEAR-USD", "STX4847-USD", "FIL-USD",
"HBAR-USD", "CRO-USD", "ATOM-USD", "ARB11841-USD", "OP-USD", "VET-USD", "MKR-USD", "INJ-USD", "ALGO-USD", "THETA-USD",
"RNDR-USD", "IMX10603-USD", "TAO22974-USD", "GRT6719-USD", "QNT-USD", "FET3773-USD", "EGLD-USD", "AAVE-USD", "XTZ-USD", "SAND-USD"
]

# %%
top_100_tickers = top_50_us_tickers + top_50_europe_tickers

START_DATE = "2000-01-01"
TODAY = datetime.now().strftime("%Y-%m-%d")

STOCKS = {
    ticker: {"tickers": ticker, "start_date": START_DATE, "end_date": TODAY}
    for ticker in top_100_tickers
    }

# %%
stocks_data = load_data(STOCKS)
df_stocks = stocks_data["Close"]
df_stocks.to_csv("test_data.csv")
# Out:
# Loading data for AAPL from 2000-01-01 to 2026-06-13...
# [*********************100%***********************]  1 of 1 completed
# Loading data for MSFT from 2000-01-01 to 2026-06-13...
# [*********************100%***********************]  1 of 1 completed
# Loading data for NVDA from 2000-01-01 to 2026-06-13...
# [*********************100%***********************]  1 of 1 completed
# Loading data for AMZN from 2000-01-01 to 2026-06-13...
# [*********************100%***********************]  1 of 1 completed
# Loading data for GOOG from 2000-01-01 to 2026-06-13...
# [*********************100%***********************]  1 of 1 completed
# Loading data for GOOGL from 2000-01-01 to 2026-06-13...
# [*********************100%***********************]  1 of 1 completed
# Loading data for META from 2000-01-01 to 2026-06-13...
# [*********************100%***********************]  1 of 1 completed
# Loading data for BRK-B from 2000-01-01 to 2026-06-13...
# ...
